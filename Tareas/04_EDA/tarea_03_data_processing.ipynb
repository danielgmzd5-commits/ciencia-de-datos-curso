# %% [markdown]
# # Tarea 03 — Procesamiento de Datos con Pandas
#
# **Instrucciones:** Completa cada celda de código con tu respuesta.
# Trabajarás con el dataset del Titanic para practicar transformaciones reales.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ---
# ## Parte 1 — Exploración y selección

# %% [markdown]
# **P1.** Imprime los nombres de todas las columnas y el número total de filas y columnas del DataFrame.

# %%
# Tu respuesta aquí

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# **P2.** Usa `.loc` para seleccionar las filas 10 a 15 (inclusive) y solo las columnas `Name`, `Age` y `Survived`.

# %%
# Tu respuesta aquí

df.loc[10:15, ["Name", "Age", "Survived"]]
# Out:
#                                     Name   Age  Survived
# 10       Sandstrom, Miss. Marguerite Rut   4.0         1
# 11              Bonnell, Miss. Elizabeth  58.0         1
# 12        Saundercock, Mr. William Henry  20.0         0
# 13           Andersson, Mr. Anders Johan  39.0         0
# 14  Vestrom, Miss. Hulda Amanda Adolfina  14.0         0
# 15      Hewlett, Mrs. (Mary D Kingcome)   55.0         1

# %% [markdown]
# ---
# ## Parte 2 — Valores nulos y limpieza

# %% [markdown]
# **P3.** Cuenta cuántos valores nulos hay en cada columna. ¿Cuáles columnas tienen nulos?

# %%
# Tu respuesta aquí

print("Valores nulos en cada columna")
df.isnull().sum()
# Out:
# Valores nulos en cada columna
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print("Columas que contienen valores nulos")
nulos = df.isnull().sum()
nulos[nulos > 0]
# Out:
# Columas que contienen valores nulos
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# **Respuesta:** Las columnas con valores nulos son: Age, Cabin y Embarked

# %% [markdown]
# **P4.** Rellena los valores nulos de la columna `Age` con la **mediana** de esa columna.
# Verifica que ya no haya nulos en `Age`.

# %%
# Tu respuesta aquí

df["Age"] = df["Age"].fillna(df["Age"].median())
print("Nulos en Age:", df["Age"].isnull().sum())
print("-------------------------------------------")
print("Verificamos nuevamente todas las columasn con nulos")
df.isnull().sum()
# Out:
# Nulos en Age: 0
# -------------------------------------------
# Verificamos nuevamente todas las columasn con nulos
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ---
# ## Parte 3 — Nuevas columnas y agrupaciones

# %% [markdown]
# **P5.** Crea una nueva columna llamada `FamilySize` que sea la suma de `SibSp` + `Parch` + 1 (el pasajero mismo).

# %%
# Tu respuesta aquí
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %% [markdown]
# **P6.** Usando `groupby`, calcula la **tasa de supervivencia promedio** (columna `Survived`) por clase (`Pclass`).
# ¿Qué clase tuvo mayor probabilidad de sobrevivir?

# %%
# Tu respuesta aquí

(df.groupby("Pclass")["Survived"].mean() * 100).round(2)
# Out:
# Pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: Survived, dtype: float64

# %% [markdown]
# **Respuesta:** La clase con mayor supervivencia fue: Primera Clase con un 62%

# %% [markdown]
# **P7.** Calcula la edad promedio y la tarifa (`Fare`) promedio, agrupando por `Sex` y `Pclass`.
# Usa `.groupby()` con `.agg()`.

# %%
# Tu respuesta aquí

df.groupby(["Sex", "Pclass"]).agg(
    edad_promedio=("Age", "mean"),
    tarifa_promedio=("Fare", "mean"),
).round(2)
# Out:
#                edad_promedio  tarifa_promedio
# Sex    Pclass
# female 1               33.98           106.13
#        2               28.70            21.97
#        3               23.57            16.12
# male   1               39.00            67.23
#        2               30.51            19.74
#        3               26.91            12.66

# %% [markdown]
# ---
# ## Parte 4 — Ordenamiento y duplicados

# %% [markdown]
# **P8.** Ordena el DataFrame por `Fare` de mayor a menor y muestra las primeras 5 filas.
# ¿Cuánto pagó el pasajero más caro?

# %%
# Tu respuesta aquí

df.sort_values("Fare", ascending=False)[["Name", "Pclass", "Fare"]].round(2).head(5)
# Out:
#                                    Name  Pclass    Fare
# 258                    Ward, Miss. Anna       1  512.33
# 737              Lesurer, Mr. Gustave J       1  512.33
# 679  Cardeza, Mr. Thomas Drake Martinez       1  512.33
# 88           Fortune, Miss. Mabel Helen       1  263.00
# 27       Fortune, Mr. Charles Alexander       1  263.00

# %% [markdown]
# **P9.** Verifica si hay filas duplicadas en el DataFrame. ¿Cuántas hay?

# %%
# Tu respuesta aquí

print("¿Hay filas duplicadas?:", df.duplicated().any())
print("Cantidad de filas duplicadas:", df.duplicated().sum())
# Out:
# ¿Hay filas duplicadas?: False
# Cantidad de filas duplicadas: 0
